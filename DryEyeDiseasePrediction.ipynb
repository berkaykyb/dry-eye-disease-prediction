# %% [markdown]
# # Numaralar ve İsimler

# %% [markdown]
# ## 152120211097 - Çağrı Elagöz
# ## 152120221072 - Berkay Kayabaşı
# ## 152120221085 - Samet Toka

# %% [markdown]
# # Data Visulization

# %%
# Temel kütüphaneler
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# İstatistiksel analizler
from scipy.stats import levene, zscore
from scipy.stats import shapiro
from scipy.stats import kstest
from scipy.stats import anderson, probplot
from scipy.stats import mannwhitneyu

# Veri ön işleme
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder

# PCA
from sklearn.decomposition import PCA

# Performans metrikleri
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    classification_report, roc_curve, auc, roc_auc_score
)

# Ensemble ve ağaç tabanlı modeller
from sklearn.ensemble import (
    RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier,
    BaggingClassifier, ExtraTreesClassifier
)
from sklearn.tree import DecisionTreeClassifier

# Lineer modeller
from sklearn.linear_model import (
    LogisticRegression, RidgeClassifier, Perceptron, SGDClassifier
)

# Naive Bayes
from sklearn.naive_bayes import GaussianNB, BernoulliNB

# Destek Vektör Makineleri
from sklearn.svm import SVC, NuSVC, LinearSVC

# Diğer modeller
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis, QuadraticDiscriminantAnalysis

# %%
df = pd.read_csv("Dry_Eye_Dataset.csv")

# %%
df.columns
# Out:
# Index(['Gender', 'Age', 'Sleep duration', 'Sleep quality', 'Stress level',
#        'Blood pressure', 'Heart rate', 'Daily steps', 'Physical activity',
#        'Height', 'Weight', 'Sleep disorder', 'Wake up during night',
#        'Feel sleepy during day', 'Caffeine consumption', 'Alcohol consumption',
#        'Smoking', 'Medical issue', 'Ongoing medication',
#        'Smart device before bed', 'Average screen time', 'Blue-light filter',
#        'Discomfort Eye-strain', 'Redness in eye',
#        'Itchiness/Irritation in eye', 'Dry Eye Disease'],
#       dtype='str')

# %%
df.head(10)
# Out:
#   Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 0      F   24             9.5              2             1         137/89
# 1      M   39             9.6              2             3         108/64
# 2      F   45             5.4              1             5         134/81
# 3      F   45             5.4              4             5         110/90
# 4      F   42             5.7              3             2          99/67
# 5      F   42             5.8              3             1         117/85
# 6      M   26             4.8              5             2         124/61
# 7      M   33             5.5              2             1         109/85
# 8      M   36             6.3              1             2         135/76
# 9      M   33             7.7              4             5         140/88
#
#    Heart rate  Daily steps  Physical activity  Height  ...  Smoking  \
# 0          67         3000                 31     161  ...        N
# 1          60        12000                 74     164  ...        N
# 2          95        12000                 93     179  ...        N
# 3          78        19000                 32     160  ...        N
# 4          72         4000                173     179  ...        N
# 5          79        14000                110     174  ...        Y
# 6          63         6000                 42     188  ...        N
# 7          97         5000                 71     162  ...        N
# 8          78         7000                142     175  ...        Y
# 9          81         4000                105     163  ...        N
#
#   Medical issue Ongoing medication Smart device before bed  \
# 0             Y                  Y                       N
# 1             Y                  Y                       N
# 2             N                  N                       Y
# 3             Y                  N                       N
# 4             Y                  N                       N
# 5             Y                  Y                       Y
# 6             Y                  Y                       Y
# 7             N                  Y                       N
# 8             Y                  N                       N
# 9             Y                  Y                       N
#
#   Average screen time Blue-light filter Discomfort Eye-strain Redness in eye  \
# 0                 8.7                 N                     Y              Y
# 1                 9.6                 Y                     N              N
# 2                 4.0                 N                     Y              N
# 3                 7.6                 N                     Y              N
# 4                 3.5                 N                     Y              Y
# 5                 2.6                 Y                     Y              N
# 6                 5.4                 Y                     N              N
# 7                 4.5                 Y                     Y              N
# 8                 3.9                 Y                     N              N
# 9                 5.7                 N                     N              Y
#
#   Itchiness/Irritation in eye Dry Eye Disease
# 0                           N               Y
# 1                           Y               Y
# 2                           N               N
# 3                           Y               N
# 4                           N               Y
# 5                           Y               Y
# 6                           Y               Y
# 7                           N               Y
# 8                           Y               N
# 9                           Y               Y
#
# [10 rows x 26 columns]

# %%
df.tail(10)
# Out:
#       Gender  Age  Sleep duration  Sleep quality  Stress level Blood pressure  \
# 19990      M   29             5.7              5             4         116/81
# 19991      F   28             8.3              4             3         102/87
# 19992      F   24             9.1              4             1          97/83
# 19993      F   28             9.0              4             5          95/87
# 19994      M   42             5.5              1             3         111/79
# 19995      M   26             9.4              2             3         132/64
# 19996      F   39             7.3              3             4         101/75
# 19997      F   20             8.0              5             3         124/63
# 19998      M   38             4.5              3             3         136/70
# 19999      M   37             5.0              5             3          96/90
#
#        Heart rate  Daily steps  Physical activity  Height  ...  Smoking  \
# 19990          62        18000                 19     196  ...        N
# 19991          65        18000                132     155  ...        N
# 19992          71        20000                130     159  ...        Y
# 19993          78         9000                178     156  ...        N
# 19994          66        12000                141     186  ...        N
# 19995          91        20000                 88     200  ...        Y
# 19996          65         2000                 53     195  ...        N
# 19997          78        10000                 17     186  ...        Y
# 19998          60         3000                115     170  ...        Y
# 19999          73        13000                 57     188  ...        N
#
#       Medical issue Ongoing medication Smart device before bed  \
# 19990             Y                  Y                       Y
# 19991             N                  Y                       Y
# 19992             Y                  N                       Y
# 19993             Y                  Y                       N
# 19994             Y                  N                       Y
# 19995             Y                  Y                       Y
# 19996             Y                  Y                       N
# 19997             Y                  N                       N
# 19998             N                  Y                       N
# 19999             Y                  Y                       Y
#
#       Average screen time Blue-light filter Discomfort Eye-strain  \
# 19990                 4.6                 Y                     N
# 19991                 2.6                 Y                     Y
# 19992                10.0                 Y                     Y
# 19993                 6.7                 Y                     N
# 19994                 9.9                 N                     Y
# 19995                 3.8                 N                     Y
# 19996                 3.8                 N                     N
# 19997                 8.4                 N                     N
# 19998                 2.2                 N                     N
# 19999                 4.2                 Y                     N
#
#       Redness in eye Itchiness/Irritation in eye Dry Eye Disease
# 19990              Y                           Y               N
# 19991              Y                           Y               Y
# 19992              Y                           Y               Y
# 19993              Y                           Y               Y
# 19994              N                           N               Y
# 19995              N                           Y               Y
# 19996              Y                           N               Y
# 19997              Y                           N               N
# 19998              N                           Y               Y
# 19999              N                           N               N
#
# [10 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       20000 non-null  str
#  1   Age                          20000 non-null  int64
#  2   Sleep duration               20000 non-null  float64
#  3   Sleep quality                20000 non-null  int64
#  4   Stress level                 20000 non-null  int64
#  5   Blood pressure               20000 non-null  str
#  6   Heart rate                   20000 non-null  int64
#  7   Daily steps                  20000 non-null  int64
#  8   Physical activity            20000 non-null  int64
#  9   Height                       20000 non-null  int64
#  10  Weight                       20000 non-null  int64
#  11  Sleep disorder               20000 non-null  str
#  12  Wake up during night         20000 non-null  str
#  13  Feel sleepy during day       20000 non-null  str
#  14  Caffeine consumption         20000 non-null  str
#  15  Alcohol consumption          20000 non-null  str
#  16  Smoking                      20000 non-null  str
#  17  Medical issue                20000 non-null  str
#  18  Ongoing medication           20000 non-null  str
#  19  Smart device before bed      20000 non-null  str
#  20  Average screen time          20000 non-null  float64
#  21  Blue-light filter            20000 non-null  str
#  22  Discomfort Eye-strain        20000 non-null  str
#  23  Redness in eye               20000 non-null  str
#  24  Itchiness/Irritation in eye  20000 non-null  str
#  25  Dry Eye Disease              20000 non-null  str
# dtypes: float64(2), int64(8), str(16)
# memory usage: 4.0 MB

# %%
df.describe()
# Out:
#                 Age  Sleep duration  Sleep quality  Stress level  \
# count  20000.000000    20000.000000   20000.000000  20000.000000
# mean      31.422800        6.998245       2.997250      2.993750
# std        8.103717        1.731723       1.412283      1.407235
# min       18.000000        4.000000       1.000000      1.000000
# 25%       24.000000        5.500000       2.000000      2.000000
# 50%       31.000000        7.000000       3.000000      3.000000
# 75%       39.000000        8.500000       4.000000      4.000000
# max       45.000000       10.000000       5.000000      5.000000
#
#          Heart rate   Daily steps  Physical activity        Height  \
# count  20000.000000  20000.000000       20000.000000  20000.000000
# mean      79.912200  10536.900000          90.069750    174.865900
# std       11.808279   5752.729186          52.317283     14.719903
# min       60.000000   1000.000000           0.000000    150.000000
# 25%       70.000000   6000.000000          45.000000    162.000000
# 50%       80.000000  11000.000000          91.000000    175.000000
# 75%       90.000000  16000.000000         135.000000    188.000000
# max      100.000000  20000.000000         180.000000    200.000000
#
#              Weight  Average screen time
# count  20000.000000         20000.000000
# mean      74.891850             5.519885
# std       14.733839             2.606305
# min       50.000000             1.000000
# 25%       62.000000             3.300000
# 50%       75.000000             5.500000
# 75%       88.000000             7.800000
# max      100.000000            10.000000

# %%
df.describe(include = "all").T
# Out:
#                                count unique     top   freq      mean  \
# Gender                         20000      2       M  10028       NaN
# Age                          20000.0    NaN     NaN    NaN   31.4228
# Sleep duration               20000.0    NaN     NaN    NaN  6.998245
# Sleep quality                20000.0    NaN     NaN    NaN   2.99725
# Stress level                 20000.0    NaN     NaN    NaN   2.99375
# Blood pressure                 20000   1581  109/73     27       NaN
# Heart rate                   20000.0    NaN     NaN    NaN   79.9122
# Daily steps                  20000.0    NaN     NaN    NaN   10536.9
# Physical activity            20000.0    NaN     NaN    NaN  90.06975
# Height                       20000.0    NaN     NaN    NaN  174.8659
# Weight                       20000.0    NaN     NaN    NaN  74.89185
# Sleep disorder                 20000      2       N  10069       NaN
# Wake up during night           20000      2       N  10000       NaN
# Feel sleepy during day         20000      2       N  10178       NaN
# Caffeine consumption           20000      2       Y  10089       NaN
# Alcohol consumption            20000      2       Y  10009       NaN
# Smoking                        20000      2       N  10017       NaN
# Medical issue                  20000      2       N  10111       NaN
# Ongoing medication             20000      2       Y  10082       NaN
# Smart device before bed        20000      2       Y  10003       NaN
# Average screen time          20000.0    NaN     NaN    NaN  5.519885
# Blue-light filter              20000      2       N  10016       NaN
# Discomfort Eye-strain          20000      2       Y  10037       NaN
# Redness in eye                 20000      2       N  10129       NaN
# Itchiness/Irritation in eye    20000      2       N  10063       NaN
# Dry Eye Disease                20000      2       Y  13037       NaN
#
#                                      std     min     25%      50%      75%  \
# Gender                               NaN     NaN     NaN      NaN      NaN
# Age                             8.103717    18.0    24.0     31.0     39.0
# Sleep duration                  1.731723     4.0     5.5      7.0      8.5
# Sleep quality                   1.412283     1.0     2.0      3.0      4.0
# Stress level                    1.407235     1.0     2.0      3.0      4.0
# Blood pressure                       NaN     NaN     NaN      NaN      NaN
# Heart rate                     11.808279    60.0    70.0     80.0     90.0
# Daily steps                  5752.729186  1000.0  6000.0  11000.0  16000.0
# Physical activity              52.317283     0.0    45.0     91.0    135.0
# Height                         14.719903   150.0   162.0    175.0    188.0
# Weight                         14.733839    50.0    62.0     75.0     88.0
# Sleep disorder                       NaN     NaN     NaN      NaN      NaN
# Wake up during night                 NaN     NaN     NaN      NaN      NaN
# Feel sleepy during day               NaN     NaN     NaN      NaN      NaN
# Caffeine consumption                 NaN     NaN     NaN      NaN      NaN
# Alcohol consumption                  NaN     NaN     NaN      NaN      NaN
# Smoking                              NaN     NaN     NaN      NaN      NaN
# Medical issue                        NaN     NaN     NaN      NaN      NaN
# Ongoing medication                   NaN     NaN     NaN      NaN      NaN
# Smart device before bed              NaN     NaN     NaN      NaN      NaN
# Average screen time             2.606305     1.0     3.3      5.5      7.8
# Blue-light filter                    NaN     NaN     NaN      NaN      NaN
# Discomfort Eye-strain                NaN     NaN     NaN      NaN      NaN
# Redness in eye                       NaN     NaN     NaN      NaN      NaN
# Itchiness/Irritation in eye          NaN     NaN     NaN      NaN      NaN
# Dry Eye Disease                      NaN     NaN     NaN      NaN      NaN
#
#                                  max
# Gender                           NaN
# Age                             45.0
# Sleep duration                  10.0
# Sleep quality                    5.0
# Stress level                     5.0
# Blood pressure                   NaN
# Heart rate                     100.0
# Daily steps                  20000.0
# Physical activity              180.0
# Height                         200.0
# Weight                         100.0
# Sleep disorder                   NaN
# Wake up during night             NaN
# Feel sleepy during day           NaN
# Caffeine consumption             NaN
# Alcohol consumption              NaN
# Smoking                          NaN
# Medical issue                    NaN
# Ongoing medication               NaN
# Smart device before bed          NaN
# Average screen time             10.0
# Blue-light filter                NaN
# Discomfort Eye-strain            NaN
# Redness in eye                   NaN
# Itchiness/Irritation in eye      NaN
# Dry Eye Disease                  NaN

# %%
df.shape
# Out:
# (20000, 26)

# %% [markdown]
# # Eksik Değer Testi

# %%
# Her sütundaki eksik (NaN) değerlerin sayısı
missing_counts = df.isnull().sum()

# Eksik veri yüzdesi
missing_percentages = (missing_counts / len(df)) * 100

# Sadece eksik verisi olan sütunları filtrele
missing_data = pd.DataFrame({
    "Eksik Deger Sayisi": missing_counts,
    "Eksik Orani (%)": missing_percentages
})
missing_data = missing_data[missing_data["Eksik Deger Sayisi"] > 0]
missing_data = missing_data.sort_values(by="Eksik Orani (%)", ascending=False)

# Sonuçları göster
print(missing_data)
# Out:
# Empty DataFrame
# Columns: [Eksik Deger Sayisi, Eksik Orani (%)]
# Index: []

# %%
df.isnull().sum()
# Out:
# Gender                         0
# Age                            0
# Sleep duration                 0
# Sleep quality                  0
# Stress level                   0
# Blood pressure                 0
# Heart rate                     0
# Daily steps                    0
# Physical activity              0
# Height                         0
# Weight                         0
# Sleep disorder                 0
# Wake up during night           0
# Feel sleepy during day         0
# Caffeine consumption           0
# Alcohol consumption            0
# Smoking                        0
# Medical issue                  0
# Ongoing medication             0
# Smart device before bed        0
# Average screen time            0
# Blue-light filter              0
# Discomfort Eye-strain          0
# Redness in eye                 0
# Itchiness/Irritation in eye    0
# Dry Eye Disease                0
# dtype: int64

# %% [markdown]
# # Kategorik Değişkenler

# %%
kat_df = df.select_dtypes(include = ["object"])
# Out:
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/2508409910.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   kat_df = df.select_dtypes(include = ["object"])

# %%
kat_df.head(10)
# Out:
#   Gender Blood pressure Sleep disorder Wake up during night  \
# 0      F         137/89              Y                    N
# 1      M         108/64              N                    N
# 2      F         134/81              Y                    Y
# 3      F         110/90              N                    N
# 4      F          99/67              N                    Y
# 5      F         117/85              Y                    N
# 6      M         124/61              Y                    N
# 7      M         109/85              N                    N
# 8      M         135/76              N                    N
# 9      M         140/88              N                    N
#
#   Feel sleepy during day Caffeine consumption Alcohol consumption Smoking  \
# 0                      N                    N                   N       N
# 1                      N                    N                   Y       N
# 2                      N                    Y                   Y       N
# 3                      N                    Y                   N       N
# 4                      N                    N                   N       N
# 5                      Y                    Y                   Y       Y
# 6                      N                    Y                   Y       N
# 7                      N                    N                   Y       N
# 8                      N                    N                   N       Y
# 9                      N                    Y                   Y       N
#
#   Medical issue Ongoing medication Smart device before bed Blue-light filter  \
# 0             Y                  Y                       N                 N
# 1             Y                  Y                       N                 Y
# 2             N                  N                       Y                 N
# 3             Y                  N                       N                 N
# 4             Y                  N                       N                 N
# 5             Y                  Y                       Y                 Y
# 6             Y                  Y                       Y                 Y
# 7             N                  Y                       N                 Y
# 8             Y                  N                       N                 Y
# 9             Y                  Y                       N                 N
#
#   Discomfort Eye-strain Redness in eye Itchiness/Irritation in eye  \
# 0                     Y              Y                           N
# 1                     N              N                           Y
# 2                     Y              N                           N
# 3                     Y              N                           Y
# 4                     Y              Y                           N
# 5                     Y              N                           Y
# 6                     N              N                           Y
# 7                     Y              N                           N
# 8                     N              N                           Y
# 9                     N              Y                           Y
#
#   Dry Eye Disease
# 0               Y
# 1               Y
# 2               N
# 3               N
# 4               Y
# 5               Y
# 6               Y
# 7               Y
# 8               N
# 9               Y

# %% [markdown]
# # Sürekli Değişkenler

# %%
continuous_cols = ['Age', 'Sleep duration', 'Heart rate', 'Daily steps', 'Average screen time', 'Height', 'Weight']
df_num = df[continuous_cols]

# %%
df_num.head(10)
# Out:
#    Age  Sleep duration  Heart rate  Daily steps  Average screen time  Height  \
# 0   24             9.5          67         3000                  8.7     161
# 1   39             9.6          60        12000                  9.6     164
# 2   45             5.4          95        12000                  4.0     179
# 3   45             5.4          78        19000                  7.6     160
# 4   42             5.7          72         4000                  3.5     179
# 5   42             5.8          79        14000                  2.6     174
# 6   26             4.8          63         6000                  5.4     188
# 7   33             5.5          97         5000                  4.5     162
# 8   36             6.3          78         7000                  3.9     175
# 9   33             7.7          81         4000                  5.7     163
#
#    Weight
# 0      69
# 1      87
# 2      94
# 3      77
# 4      99
# 5      64
# 6      82
# 7      91
# 8      80
# 9      65

# %% [markdown]
# # Aykırı Değer

# %%
# Sadece sayısal sütunları seç
numeric_columns = df.select_dtypes(include=[np.number])

# Z-score hesapla
z_scores = zscore(numeric_columns)

# Aykırı değer bayrakları: |z| > 3
outlier_flags = (np.abs(z_scores) > 3)

# Her sütunda aykırı değer sayısını topla
outlier_counts = outlier_flags.sum(axis=0)


# Aykırı değerleri tespit et IQR yöntemi ile
# IQR (Interquartile Range) yöntemi ile aykırı değerleri tespit et
# Q1 ve Q3 hesapla
for column in numeric_columns.columns:
    Q1 = numeric_columns[column].quantile(0.25)
    Q3 = numeric_columns[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = numeric_columns[(numeric_columns[column] < lower_bound) | (numeric_columns[column] > upper_bound)]


# Aykırı özet tablosu
outlier_summary = pd.DataFrame({
    "Aykiri Deger Sayisi": outlier_counts,
    "Toplam Gozlem Sayisi": len(df),
    "Aykiri Orani (%)": (outlier_counts / len(df)) * 100
})
outlier_summary = outlier_summary[outlier_summary["Aykiri Deger Sayisi"] > 0]
outlier_summary = outlier_summary.sort_values(by="Aykiri Orani (%)", ascending=False)

print(outlier_summary)
# Out:
# Empty DataFrame
# Columns: [Aykiri Deger Sayisi, Toplam Gozlem Sayisi, Aykiri Orani (%)]
# Index: []

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Shapiro-Wilk

# %%
results = []

for col in numeric_columns:
    stat, p = shapiro(df[col])
    results.append({
        "Sütun": col,
        "p-değeri": round(p, 5),
        "Sonuç": "NORMAL" if p >= 0.05 else "NORMAL DEĞİL"
    })

shapiro_df = pd.DataFrame(results)
print(shapiro_df)
# Out:
#                  Sütun  p-değeri         Sonuç
# 0                  Age       0.0  NORMAL DEĞİL
# 1       Sleep duration       0.0  NORMAL DEĞİL
# 2        Sleep quality       0.0  NORMAL DEĞİL
# 3         Stress level       0.0  NORMAL DEĞİL
# 4           Heart rate       0.0  NORMAL DEĞİL
# 5          Daily steps       0.0  NORMAL DEĞİL
# 6    Physical activity       0.0  NORMAL DEĞİL
# 7               Height       0.0  NORMAL DEĞİL
# 8               Weight       0.0  NORMAL DEĞİL
# 9  Average screen time       0.0  NORMAL DEĞİL
# /Users/berkaykayabasi/Desktop/DryEyeDisease/.venv/lib/python3.14/site-packages/scipy/stats/_axis_nan_policy.py:592: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 20000.
#   res = hypotest_fun_out(*samples, **kwds)

# %% [markdown]
# ## Kolmogorov-Smirnov

# %%
numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns

print("Kolmogorov-Smirnov Testi Sonuçları:\n")

for col in numeric_cols:
    data = df[col].dropna()  # boş veriler varsa temizle
    standardized = (data - data.mean()) / data.std()  # veriyi z-puanına getir
    stat, p = kstest(standardized, 'norm')  # teorik dağılım: normal ('norm')
    print(f"{col:<30} → p-value: {p:} → {'NORMAL' if p >= 0.05 else 'NORMAL DEGIL'}")
# Out:
# Kolmogorov-Smirnov Testi Sonuçları:
#
# Age                            → p-value: 4.189267564050334e-99 → NORMAL DEGIL
# Sleep duration                 → p-value: 1.1450054308642452e-77 → NORMAL DEGIL
# Sleep quality                  → p-value: 0.0 → NORMAL DEGIL
# Stress level                   → p-value: 0.0 → NORMAL DEGIL
# Heart rate                     → p-value: 1.1070388082640335e-84 → NORMAL DEGIL
# Daily steps                    → p-value: 1.1570293624917302e-120 → NORMAL DEGIL
# Physical activity              → p-value: 5.582513946732409e-62 → NORMAL DEGIL
# Height                         → p-value: 1.6570900882246556e-87 → NORMAL DEGIL
# Weight                         → p-value: 4.7655318948028986e-85 → NORMAL DEGIL
# Average screen time            → p-value: 4.583549379008645e-76 → NORMAL DEGIL

# %% [markdown]
# ## Anderson-Darling

# %%
def anderson_kde_qq_all(df):
    numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns

    for col in numeric_cols:
        data = df[col].dropna()
        result = anderson(data)

        # Anderson çıktısı
        print(f"\nAnderson-Darling Testi - {col}")
        print(f"Test İstatistiği: {result.statistic:.4f}")
        for i in range(len(result.critical_values)):
            sig_level = result.significance_level[i]
            crit_value = result.critical_values[i]
            if result.statistic < crit_value:
                print(f"  → %{sig_level} seviyesinde: NORMAL (kritik değer: {crit_value} > {result.statistic:.4f})")
            else:
                print(f"  → %{sig_level} seviyesinde: NORMAL DEĞİL (kritik değer: {crit_value} < {result.statistic:.4f})")

        # KDE + Q-Q Plot
        plt.figure(figsize=(12, 4))

        # KDE
        plt.subplot(1, 2, 1)
        sns.kdeplot(data, fill=True, color='steelblue')
        plt.title(f"KDE - {col}")
        plt.xlabel(col)

        # Q-Q Plot
        plt.subplot(1, 2, 2)
        probplot(data, dist="norm", plot=plt)
        plt.title(f"Q-Q Plot - {col}")

        plt.tight_layout()
        plt.show()

anderson_kde_qq_all(df)
# Out:
# Anderson-Darling Testi - Age
# Test İstatistiği: 237.7844
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 237.7844)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 237.7844)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 237.7844)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 237.7844)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 237.7844)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Sleep duration
# Test İstatistiği: 222.0933
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 222.0933)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 222.0933)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 222.0933)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 222.0933)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 222.0933)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Sleep quality
# Test İstatistiği: 715.2210
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 715.2210)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 715.2210)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 715.2210)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 715.2210)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 715.2210)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Stress level
# Test İstatistiği: 706.1816
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 706.1816)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 706.1816)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 706.1816)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 706.1816)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 706.1816)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Heart rate
# Test İstatistiği: 225.6807
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 225.6807)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 225.6807)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 225.6807)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 225.6807)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 225.6807)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Daily steps
# Test İstatistiği: 247.9099
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 247.9099)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 247.9099)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 247.9099)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 247.9099)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 247.9099)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Physical activity
# Test İstatistiği: 220.2539
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 220.2539)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 220.2539)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 220.2539)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 220.2539)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 220.2539)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Height
# Test İstatistiği: 235.5681
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 235.5681)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 235.5681)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 235.5681)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 235.5681)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 235.5681)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Weight
# Test İstatistiği: 233.5121
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 233.5121)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 233.5121)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 233.5121)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 233.5121)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 233.5121)
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/3561109891.py:6: FutureWarning: As of SciPy 1.17, users must choose a p-value calculation method by providing the `method` parameter. `method='interpolate'` interpolates the p-value from pre-calculated tables; `method` may also be an instance of `MonteCarloMethod` to approximate the p-value via Monte Carlo simulation. When `method` is specified, the result object will include a `pvalue` attribute and not attributes `critical_value`, `significance_level`, or `fit_result`. Beginning in 1.19.0, these other attributes will no longer be available, and a p-value will always be computed according to one of the available `method` options.
#   result = anderson(data)
# Anderson-Darling Testi - Average screen time
# Test İstatistiği: 226.4723
#   → %15.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.561 < 226.4723)
#   → %10.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.631 < 226.4723)
#   → %5.0 seviyesinde: NORMAL DEĞİL (kritik değer: 0.752 < 226.4723)
#   → %2.5 seviyesinde: NORMAL DEĞİL (kritik değer: 0.873 < 226.4723)
#   → %1.0 seviyesinde: NORMAL DEĞİL (kritik değer: 1.035 < 226.4723)

# %% [markdown]
# ## Mann Whitney

# %%
def mann_whitney_all(df, target_col="Dry Eye Disease", alpha=0.05):
    # Ensure the target column is excluded from numeric columns
    numeric_cols = df.select_dtypes(include=["int64", "float64"]).columns
    numeric_cols = numeric_cols.drop(target_col, errors='ignore')
    results = []

    for col in numeric_cols:
        group_1 = df[df[target_col] == "Y"][col].dropna()  # Assuming "Y" represents 1
        group_0 = df[df[target_col] == "N"][col].dropna()  # Assuming "N" represents 0
        
        # En az 2 veri olması gerekir
        if len(group_1) > 1 and len(group_0) > 1:
            stat, p = mannwhitneyu(group_1, group_0, alternative='two-sided')
            results.append({
                "Değişken": col,
                "U İstatistiği": round(stat, 2),
                "p-değeri": round(p, 5),
                "Farklılık": "ANLAMLI" if p < alpha else "YOK"
            })

    # DataFrame olarak göster
    results_df = pd.DataFrame(results).sort_values(by="p-değeri")
    return results_df

mann_results = mann_whitney_all(df)
print(mann_results)
# Out:
#               Değişken  U İstatistiği  p-değeri Farklılık
# 9  Average screen time     46627880.0   0.00144   ANLAMLI
# 7               Height     45032773.5   0.36060       YOK
# 5          Daily steps     45699209.0   0.42356       YOK
# 3         Stress level     45682957.5   0.43945       YOK
# 0                  Age     45671544.5   0.46624       YOK
# 2        Sleep quality     45119711.5   0.48095       YOK
# 6    Physical activity     45206961.5   0.64104       YOK
# 8               Weight     45524949.0   0.72534       YOK
# 4           Heart rate     45271298.0   0.76347       YOK
# 1       Sleep duration     45342140.0   0.90549       YOK

# %% [markdown]
# ## Histogram ve Yoğunluk

# %%
numerical_col=df.select_dtypes(include="number")
for col in numerical_col.columns:
    plt.figure(figsize=(8,3))
    sns.histplot(data=numerical_col[col],kde=True,bins=30)
    plt.title(f"Histogram of {col}")
    plt.show()

# %% [markdown]
# ## Boxplot

# %%
plt.figure(figsize=(6, 5 * len(numerical_col.columns)))  
for i, col in enumerate(numerical_col.columns, 1):
    plt.subplot(len(numerical_col.columns), 1, i) 
    sns.boxplot(data=numerical_col[col])
    plt.title(f"Boxplot for {col}")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Çaprazlamalar

# %% [markdown]
# ## Cinsiyet ve Göz Kuruluğu Hastalığı

# %% [markdown]
# ### Kadın ve erkeklerde göz kuruluğu hastalığı görülme sıklığını gösterir.

# %%
sns.countplot(x="Gender", hue="Dry Eye Disease", data=df)
plt.title("Cinsiyet ve Göz Kuruluğu Hastalığı İlişkisi")
plt.show()

# %%
from scipy.stats import chi2_contingency

table = pd.crosstab(df["Gender"], df["Dry Eye Disease"])
chi2, p, dof, expected = chi2_contingency(table)
print(f"Chi-Square Test: p-value = {p}")
# Out:
# Chi-Square Test: p-value = 0.021828490579784626

# %% [markdown]
# ## Ekran Süresi ile Göz Kuruluğu Hastalığı

# %% [markdown]
# ### Göz kuruluğu hastalığı olan bireylerin ekran süresi daha mı uzun?

# %%
sns.boxplot(x="Dry Eye Disease", y="Average screen time", data=df)
plt.title("Göz Kuruluğu Hastalığı ve Ortalama Ekran Süresi")
plt.show()

# %%
from scipy.stats import chi2_contingency

table = pd.crosstab(df["Average screen time"], df["Dry Eye Disease"])
chi2, p, dof, expected = chi2_contingency(table)
print(f"Chi-Square Test: p-value = {p}")
# Out:
# Chi-Square Test: p-value = 0.3787346128668557

# %% [markdown]
# ## Çapraz Tablo

# %% [markdown]
# ### Bu tablo, cinsiyete göre göz kuruluğu görülme oranlarını yüzde olarak gösterir.

# %%
pd.crosstab(df["Gender"], df["Dry Eye Disease"], normalize='index') * 100
# Out:
# Dry Eye Disease          N          Y
# Gender
# F                34.035299  65.964701
# M                35.590347  64.409653

# %% [markdown]
# ## Mavi Işık Filtresi Kullanımı ve Göz Yorgunluğu

# %% [markdown]
# ### Mavi ışık filtresi kullananlar arasında göz yorgunluğu daha mı az?

# %%
sns.countplot(x="Blue-light filter", hue="Discomfort Eye-strain", data=df)
plt.title("Mavi Işık Filtresi Kullanımı ve Göz Yorgunluğu")
plt.show()

# %%
from scipy.stats import chi2_contingency

table = pd.crosstab(df["Blue-light filter"], df["Discomfort Eye-strain"])
chi2, p, dof, expected = chi2_contingency(table)
print(f"Chi-Square Test: p-value = {p}")
# Out:
# Chi-Square Test: p-value = 0.11959285919922218

# %% [markdown]
# ## Cinsiyet, Mavi Işık Filtesi Kullanımı ve Göz Kuruluğu Hastalığı

# %%
cross = pd.crosstab(index=[df["Gender"], df["Blue-light filter"]], 
                    columns=df["Dry Eye Disease"])
sns.heatmap(cross, annot=True, fmt="d", cmap="coolwarm")
plt.title("Cinsiyet ve Mavi Işık Filtresi ile Göz Kuruluğu Dağılımı")
plt.show()

# %% [markdown]
# # Replace

# %%
object_col=df.select_dtypes(include="object")
df[object_col.columns] = object_col.replace({"Y": 1, "N": 0})
# Out:
# /var/folders/98/nh34m_9d22n1v8bwsdtb7j040000gn/T/ipykernel_67221/1378147234.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   object_col=df.select_dtypes(include="object")

# %%
df["Gender"]=df["Gender"].replace({"F":0,"M":1})

# %%
le=LabelEncoder()
df["Blood pressure"]=le.fit_transform(df["Blood pressure"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 26 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Gender                       20000 non-null  object
#  1   Age                          20000 non-null  int64
#  2   Sleep duration               20000 non-null  float64
#  3   Sleep quality                20000 non-null  int64
#  4   Stress level                 20000 non-null  int64
#  5   Blood pressure               20000 non-null  int64
#  6   Heart rate                   20000 non-null  int64
#  7   Daily steps                  20000 non-null  int64
#  8   Physical activity            20000 non-null  int64
#  9   Height                       20000 non-null  int64
#  10  Weight                       20000 non-null  int64
#  11  Sleep disorder               20000 non-null  object
#  12  Wake up during night         20000 non-null  object
#  13  Feel sleepy during day       20000 non-null  object
#  14  Caffeine consumption         20000 non-null  object
#  15  Alcohol consumption          20000 non-null  object
#  16  Smoking                      20000 non-null  object
#  17  Medical issue                20000 non-null  object
#  18  Ongoing medication           20000 non-null  object
#  19  Smart device before bed      20000 non-null  object
#  20  Average screen time          20000 non-null  float64
#  21  Blue-light filter            20000 non-null  object
#  22  Discomfort Eye-strain        20000 non-null  object
#  23  Redness in eye               20000 non-null  object
#  24  Itchiness/Irritation in eye  20000 non-null  object
#  25  Dry Eye Disease              20000 non-null  object
# dtypes: float64(2), int64(9), object(15)
# memory usage: 4.0+ MB

# %% [markdown]
# # Korelasyon

# %%
plt.figure(figsize=(12,9))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#                                Gender       Age  Sleep duration  \
# Gender                       1.000000 -0.007612       -0.014073
# Age                         -0.007612  1.000000        0.004857
# Sleep duration              -0.014073  0.004857        1.000000
# Sleep quality               -0.005695  0.002513       -0.006892
# Stress level                -0.006703  0.008379       -0.006088
# Blood pressure              -0.004377 -0.006273       -0.005137
# Heart rate                  -0.000208 -0.001196       -0.029175
# Daily steps                 -0.000505  0.001302        0.002823
# Physical activity           -0.000253 -0.009191        0.001858
# Height                       0.006942 -0.005171        0.005259
# Weight                      -0.001585  0.003908        0.000222
# Sleep disorder              -0.003881 -0.017633        0.013278
# Wake up during night        -0.006800  0.005208        0.005720
# Feel sleepy during day      -0.006751 -0.007254        0.005270
# Caffeine consumption        -0.009325 -0.001205       -0.008350
# Alcohol consumption          0.005498  0.018994       -0.005020
# Smoking                      0.005905 -0.003293       -0.003637
# Medical issue               -0.001269 -0.010528       -0.001804
# Ongoing medication           0.005377  0.007507       -0.000208
# Smart device before bed     -0.001701  0.003810       -0.003081
# Average screen time         -0.018310  0.003177       -0.004208
# Blue-light filter            0.009805 -0.002508        0.002034
# Discomfort Eye-strain       -0.010110 -0.001069        0.006544
# Redness in eye               0.007337 -0.010335        0.004315
# Itchiness/Irritation in eye -0.000282  0.009893       -0.007170
# Dry Eye Disease             -0.016321  0.005258       -0.000874
#
#                              Sleep quality  Stress level  Blood pressure  \
# Gender                           -0.005695     -0.006703       -0.004377
# Age                               0.002513      0.008379       -0.006273
# Sleep duration                   -0.006892     -0.006088       -0.005137
# Sleep quality                     1.000000      0.000721       -0.000433
# Stress level                      0.000721      1.000000        0.007032
# Blood pressure                   -0.000433      0.007032        1.000000
# Heart rate                       -0.014326     -0.008332       -0.004331
# Daily steps                      -0.003074     -0.005978       -0.001340
# Physical activity                -0.010329      0.004272       -0.006392
# Height                            0.009380     -0.000651       -0.012364
# Weight                            0.005604     -0.000611       -0.010572
# Sleep disorder                   -0.000474     -0.005467        0.001880
# Wake up during night              0.011436      0.007568       -0.003674
# Feel sleepy during day            0.008145      0.007561       -0.013076
# Caffeine consumption              0.003947      0.006542        0.004035
# Alcohol consumption               0.003578      0.007714        0.006657
# Smoking                           0.006971      0.001165        0.010502
# Medical issue                     0.000297      0.010931       -0.009154
# Ongoing medication                0.005858     -0.008172        0.003406
# Smart device before bed          -0.005133     -0.002450        0.003655
# Average screen time               0.004697     -0.001344       -0.000365
# Blue-light filter                -0.007969     -0.002317        0.016279
# Discomfort Eye-strain             0.001459      0.003889       -0.009773
# Redness in eye                    0.002843      0.011989        0.001880
# Itchiness/Irritation in eye      -0.002597     -0.004114       -0.000066
# Dry Eye Disease                  -0.004990      0.005481        0.010954
#
#                              Heart rate  Daily steps  Physical activity  \
# Gender                        -0.000208    -0.000505          -0.000253
# Age                           -0.001196     0.001302          -0.009191
# Sleep duration                -0.029175     0.002823           0.001858
# Sleep quality                 -0.014326    -0.003074          -0.010329
# Stress level                  -0.008332    -0.005978           0.004272
# Blood pressure                -0.004331    -0.001340          -0.006392
# Heart rate                     1.000000    -0.001899           0.001334
# Daily steps                   -0.001899     1.000000           0.008413
# Physical activity              0.001334     0.008413           1.000000
# Height                        -0.005229    -0.016801          -0.005989
# Weight                        -0.009639    -0.000619           0.016160
# Sleep disorder                -0.005683    -0.001233          -0.003981
# Wake up during night          -0.001702     0.003807           0.005982
# Feel sleepy during day        -0.002301     0.001835          -0.007699
# Caffeine consumption          -0.003982     0.008783          -0.001787
# Alcohol consumption            0.005664    -0.001596          -0.007275
# Smoking                       -0.010954     0.001810          -0.000228
# Medical issue                  0.003898    -0.006352          -0.000766
# Ongoing medication            -0.012871    -0.007528           0.002152
# Smart device before bed       -0.007891    -0.000237           0.004275
# Average screen time            0.002467    -0.008670           0.006469
# Blue-light filter              0.008719     0.006512           0.012624
# Discomfort Eye-strain          0.019235     0.000107           0.001386
# Redness in eye                -0.004331     0.000735           0.000689
# Itchiness/Irritation in eye   -0.000182    -0.008069           0.004153
# Dry Eye Disease               -0.002083     0.005664          -0.003289
#
#                                Height  ...   Smoking  Medical issue  \
# Gender                       0.006942  ...  0.005905      -0.001269
# Age                         -0.005171  ... -0.003293      -0.010528
# Sleep duration               0.005259  ... -0.003637      -0.001804
# Sleep quality                0.009380  ...  0.006971       0.000297
# Stress level                -0.000651  ...  0.001165       0.010931
# Blood pressure              -0.012364  ...  0.010502      -0.009154
# Heart rate                  -0.005229  ... -0.010954       0.003898
# Daily steps                 -0.016801  ...  0.001810      -0.006352
# Physical activity           -0.005989  ... -0.000228      -0.000766
# Height                       1.000000  ...  0.008979      -0.006909
# Weight                      -0.000974  ... -0.004787       0.000383
# Sleep disorder              -0.002128  ... -0.001612      -0.002477
# Wake up during night        -0.010265  ...  0.013500      -0.005300
# Feel sleepy during day       0.001801  ...  0.017873       0.016706
# Caffeine consumption        -0.007508  ...  0.001615       0.003899
# Alcohol consumption          0.010097  ...  0.004402       0.000610
# Smoking                      0.008979  ...  1.000000      -0.004219
# Medical issue               -0.006909  ... -0.004219       1.000000
# Ongoing medication           0.012976  ...  0.001714      -0.012810
# Smart device before bed     -0.004522  ... -0.006800      -0.003997
# Average screen time          0.012817  ... -0.002188       0.008951
# Blue-light filter           -0.002263  ... -0.007503       0.002882
# Discomfort Eye-strain       -0.008730  ... -0.001194       0.007242
# Redness in eye               0.000840  ...  0.000178      -0.013545
# Itchiness/Irritation in eye  0.007321  ... -0.009411      -0.012671
# Dry Eye Disease             -0.006437  ... -0.005126      -0.001080
#
#                              Ongoing medication  Smart device before bed  \
# Gender                                 0.005377                -0.001701
# Age                                    0.007507                 0.003810
# Sleep duration                        -0.000208                -0.003081
# Sleep quality                          0.005858                -0.005133
# Stress level                          -0.008172                -0.002450
# Blood pressure                         0.003406                 0.003655
# Heart rate                            -0.012871                -0.007891
# Daily steps                           -0.007528                -0.000237
# Physical activity                      0.002152                 0.004275
# Height                                 0.012976                -0.004522
# Weight                                -0.012425                 0.000990
# Sleep disorder                         0.000357                -0.002398
# Wake up during night                  -0.002000                 0.008900
# Feel sleepy during day                -0.009456                 0.007707
# Caffeine consumption                   0.005227                -0.013003
# Alcohol consumption                    0.003093                 0.007200
# Smoking                                0.001714                -0.006800
# Medical issue                         -0.012810                -0.003997
# Ongoing medication                     1.000000                 0.010498
# Smart device before bed                0.010498                 1.000000
# Average screen time                   -0.014860                 0.004573
# Blue-light filter                     -0.004187                 0.001500
# Discomfort Eye-strain                 -0.000330                 0.012599
# Redness in eye                        -0.000794                -0.004597
# Itchiness/Irritation in eye           -0.019049                 0.002602
# Dry Eye Disease                       -0.004188                -0.013320
#
#                              Average screen time  Blue-light filter  \
# Gender                                 -0.018310           0.009805
# Age                                     0.003177          -0.002508
# Sleep duration                         -0.004208           0.002034
# Sleep quality                           0.004697          -0.007969
# Stress level                           -0.001344          -0.002317
# Blood pressure                         -0.000365           0.016279
# Heart rate                              0.002467           0.008719
# Daily steps                            -0.008670           0.006512
# Physical activity                       0.006469           0.012624
# Height                                  0.012817          -0.002263
# Weight                                  0.007798           0.008340
# Sleep disorder                         -0.007266           0.004089
# Wake up during night                   -0.007185           0.006800
# Feel sleepy during day                  0.000867           0.007573
# Caffeine consumption                   -0.011923           0.010315
# Alcohol consumption                    -0.011140           0.004101
# Smoking                                -0.002188          -0.007503
# Medical issue                           0.008951           0.002882
# Ongoing medication                     -0.014860          -0.004187
# Smart device before bed                 0.004573           0.001500
# Average screen time                     1.000000          -0.001755
# Blue-light filter                      -0.001755           1.000000
# Discomfort Eye-strain                   0.009731           0.011106
# Redness in eye                          0.000534           0.000279
# Itchiness/Irritation in eye             0.006538          -0.000510
# Dry Eye Disease                         0.022490           0.005023
#
#                              Discomfort Eye-strain  Redness in eye  \
# Gender                                   -0.010110        0.007337
# Age                                      -0.001069       -0.010335
# Sleep duration                            0.006544        0.004315
# Sleep quality                             0.001459        0.002843
# Stress level                              0.003889        0.011989
# Blood pressure                           -0.009773        0.001880
# Heart rate                                0.019235       -0.004331
# Daily steps                               0.000107        0.000735
# Physical activity                         0.001386        0.000689
# Height                                   -0.008730        0.000840
# Weight                                    0.006146        0.008611
# Sleep disorder                            0.013826       -0.001689
# Wake up during night                      0.014700       -0.004100
# Feel sleepy during day                    0.009567        0.007272
# Caffeine consumption                      0.005967        0.000715
# Alcohol consumption                      -0.005603       -0.002189
# Smoking                                  -0.001194        0.000178
# Medical issue                             0.007242       -0.013545
# Ongoing medication                       -0.000330       -0.000794
# Smart device before bed                   0.012599       -0.004597
# Average screen time                       0.009731        0.000534
# Blue-light filter                         0.011106        0.000279
# Discomfort Eye-strain                     1.000000       -0.008153
# Redness in eye                           -0.008153        1.000000
# Itchiness/Irritation in eye               0.000623        0.003719
# Dry Eye Disease                           0.109866        0.103410
#
#                              Itchiness/Irritation in eye  Dry Eye Disease
# Gender                                         -0.000282        -0.016321
# Age                                             0.009893         0.005258
# Sleep duration                                 -0.007170        -0.000874
# Sleep quality                                  -0.002597        -0.004990
# Stress level                                   -0.004114         0.005481
# Blood pressure                                 -0.000066         0.010954
# Heart rate                                     -0.000182        -0.002083
# Daily steps                                    -0.008069         0.005664
# Physical activity                               0.004153        -0.003289
# Height                                          0.007321        -0.006437
# Weight                                         -0.012308         0.002450
# Sleep disorder                                 -0.006844         0.002619
# Wake up during night                            0.004100        -0.000315
# Feel sleepy during day                         -0.006013         0.004730
# Caffeine consumption                           -0.001344         0.002831
# Alcohol consumption                            -0.006994         0.011258
# Smoking                                        -0.009411        -0.005126
# Medical issue                                  -0.012671        -0.001080
# Ongoing medication                             -0.019049        -0.004188
# Smart device before bed                         0.002602        -0.013320
# Average screen time                             0.006538         0.022490
# Blue-light filter                              -0.000510         0.005023
# Discomfort Eye-strain                           0.000623         0.109866
# Redness in eye                                  0.003719         0.103410
# Itchiness/Irritation in eye                     1.000000         0.101300
# Dry Eye Disease                                 0.101300         1.000000
#
# [26 rows x 26 columns]

# %% [markdown]
# # PCA

# %%
X = df.drop("Dry Eye Disease", axis=1)
X = X.select_dtypes(include=["int64", "float64"]).dropna()

y = df.loc[X.index, "Dry Eye Disease"]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

pca_df = pd.DataFrame(data=X_pca, columns=["PCA 1", "PCA 2"])
pca_df["Dry Eye Disease"] = y.values

sns.set(style="whitegrid")
plt.figure(figsize=(10, 6))

sns.scatterplot(
    data=pca_df,
    x="PCA 1",
    y="PCA 2",
    hue="Dry Eye Disease",
    palette="Set1",
    s=60,              
    edgecolor="gray",  
    alpha=0.6
)          

plt.title("PCA Görselleştirmesi: Göz Kuruluğu Hastalığına Göre Dağılım", fontsize=14)
plt.xlabel("1. Ana Bileşen (PCA 1)", fontsize=12)
plt.ylabel("2. Ana Bileşen (PCA 2)", fontsize=12)
plt.legend(title="Dry Eye Disease", loc="best", fontsize=10, title_fontsize=11)

plt.grid(True, linestyle="--", alpha=0.3)
plt.tight_layout()
plt.show()

explained_variance = pca.explained_variance_ratio_.sum() * 100
print(f"\nİlk 2 PCA bileşeni toplam varyansın %{explained_variance:.2f} kadarını açıklamaktadır.")
# Out:
# İlk 2 PCA bileşeni toplam varyansın %18.80 kadarını açıklamaktadır.

# %%
x=df.drop(["Dry Eye Disease"],axis=1)
y=df["Dry Eye Disease"]
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# y_train ve y_test'i integer'a dönüştür
y_train = y_train.astype(int)
y_test = y_test.astype(int)

ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %%
# y_train kontrolü
print("y_train tipi:", type(y_train))
print("y_train dtype:", y_train.dtype)
print("y_train ilk 10 değer:\n", y_train.head(10))
print("\ny_train unique değerler:", y_train.unique())
print("y_train null sayısı:", y_train.isna().sum())
print("y_train shape:", y_train.shape)
# Out:
# y_train tipi: <class 'pandas.Series'>
# y_train dtype: int64
# y_train ilk 10 değer:
#  5514     0
# 1266     0
# 5864     0
# 15865    1
# 12892    0
# 5742     1
# 13653    1
# 3780     0
# 12574    0
# 15733    0
# Name: Dry Eye Disease, dtype: int64
#
# y_train unique değerler: [0 1]
# y_train null sayısı: 0
# y_train shape: (15000,)

# %% [markdown]
# # Model

# %%
models = {
    "Random Forest Classifier": RandomForestClassifier(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "AdaBoost Classifier": AdaBoostClassifier(),
    "Gradient Boosting Classifier": GradientBoostingClassifier(),
    "Bagging Classifier": BaggingClassifier(),
    "Extra Trees Classifier": ExtraTreesClassifier(),
    "Logistic Regression": LogisticRegression(),
    "Ridge Classifier": RidgeClassifier(),
    "Perceptron": Perceptron(),
    "SGD Classifier": SGDClassifier(),
    "Gaussian Naive Bayes": GaussianNB(),
    "Bernoulli Naive Bayes": BernoulliNB(),
    "Support Vector Classifier (SVC)": SVC(),
    "Nu-Support Vector Classifier": NuSVC(),
    "Linear SVC": LinearSVC(),
    "K-Nearest Neighbors": KNeighborsClassifier(),
    "Linear Discriminant Analysis": LinearDiscriminantAnalysis(),
    "Quadratic Discriminant Analysis": QuadraticDiscriminantAnalysis()
}

# %%
# Model performanslarının çıktısı
for name, model in models.items():
    try:
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        print(f"\n{name}")
        print(classification_report(y_test, y_pred))
    except Exception as e:
        print(f"{name} modelinde hata: {e}")
# Out:
# Random Forest Classifier
#               precision    recall  f1-score   support
#
#            0       0.61      0.23      0.33      1646
#            1       0.71      0.93      0.81      3354
#
#     accuracy                           0.70      5000
#    macro avg       0.66      0.58      0.57      5000
# weighted avg       0.68      0.70      0.65      5000
#
#
# Decision Tree Classifier
#               precision    recall  f1-score   support
#
#            0       0.35      0.40      0.37      1646
#            1       0.68      0.64      0.66      3354
#
#     accuracy                           0.56      5000
#    macro avg       0.51      0.52      0.51      5000
# weighted avg       0.57      0.56      0.56      5000
#
#
# AdaBoost Classifier
#               precision    recall  f1-score   support
#
#            0       0.63      0.17      0.26      1646
#            1       0.70      0.95      0.81      3354
#
#     accuracy                           0.69      5000
#    macro avg       0.66      0.56      0.54      5000
# weighted avg       0.68      0.69      0.63      5000
#
#
# Gradient Boosting Classifier
#               precision    recall  f1-score   support
#
#            0       0.63      0.23      0.34      1646
#            1       0.71      0.93      0.81      3354
#
#     accuracy                           0.70      5000
#    macro avg       0.67      0.58      0.57      5000
# weighted avg       0.68      0.70      0.65      5000
#
#
# Bagging Classifier
#               precision    recall  f1-score   support
#
#            0       0.42      0.39      0.40      1646
#            1       0.71      0.73      0.72      3354
#
#     accuracy                           0.62      5000
#    macro avg       0.56      0.56      0.56      5000
# weighted avg       0.61      0.62      0.62      5000
#
#
# Extra Trees Classifier
#               precision    recall  f1-score   support
#
#            0       0.60      0.23      0.33      1646
#            1       0.71      0.92      0.80      3354
#
#     accuracy                           0.70      5000
#    macro avg       0.65      0.58      0.57      5000
# weighted avg       0.67      0.70      0.65      5000
#
#
# Logistic Regression
#               precision    recall  f1-score   support
#
#            0       0.62      0.17      0.27      1646
#            1       0.70      0.95      0.81      3354
#
#     accuracy                           0.69      5000
#    macro avg       0.66      0.56      0.54      5000
# weighted avg       0.67      0.69      0.63      5000
#
#
# Ridge Classifier
#               precision    recall  f1-score   support
#
#            0       0.61      0.14      0.23      1646
#            1       0.69      0.95      0.80      3354
#
#     accuracy                           0.69      5000
#    macro avg       0.65      0.55      0.52      5000
# weighted avg       0.67      0.69      0.61      5000
#
#
# Perceptron
#               precision    recall  f1-score   support
#
#            0       0.34      0.49      0.40      1646
#            1       0.68      0.52      0.59      3354
#
#     accuracy                           0.51      5000
#    macro avg       0.51      0.51      0.49      5000
# weighted avg       0.56      0.51      0.53      5000
#
#
# SGD Classifier
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1646
#            1       0.67      1.00      0.80      3354
#
#     accuracy                           0.67      5000
#    macro avg       0.34      0.50      0.40      5000
# weighted avg       0.45      0.67      0.54      5000
#
#
# Gaussian Naive Bayes
#               precision    recall  f1-score   support
#
#            0       0.62      0.17      0.26      1646
#            1       0.70      0.95      0.81      3354
#
#     accuracy                           0.69      5000
#    macro avg       0.66      0.56      0.53      5000
# weighted avg       0.67      0.69      0.63      5000
#
#
# Bernoulli Naive Bayes
#               precision    recall  f1-score   support
#
#            0       0.62      0.16      0.25      1646
#            1       0.70      0.95      0.81      3354
#
#     accuracy                           0.69      5000
#    macro avg       0.66      0.55      0.53      5000
# weighted avg       0.67      0.69      0.62      5000
# /Users/berkaykayabasi/Desktop/DryEyeDisease/.venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/berkaykayabasi/Desktop/DryEyeDisease/.venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /Users/berkaykayabasi/Desktop/DryEyeDisease/.venv/lib/python3.14/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# Support Vector Classifier (SVC)
#               precision    recall  f1-score   support
#
#            0       0.63      0.23      0.34      1646
#            1       0.71      0.93      0.81      3354
#
#     accuracy                           0.70      5000
#    macro avg       0.67      0.58      0.57      5000
# weighted avg       0.68      0.70      0.65      5000
#
#
# Nu-Support Vector Classifier
#               precision    recall  f1-score   support
#
#            0       0.40      0.34      0.37      1646
#            1       0.70      0.75      0.72      3354
#
#     accuracy                           0.61      5000
#    macro avg       0.55      0.54      0.54      5000
# weighted avg       0.60      0.61      0.60      5000
#
#
# Linear SVC
#               precision    recall  f1-score   support
#
#            0       0.61      0.14      0.23      1646
#            1       0.69      0.95      0.80      3354
#
#     accuracy                           0.69      5000
#    macro avg       0.65      0.55      0.52      5000
# weighted avg       0.67      0.69      0.61      5000
#
#
# K-Nearest Neighbors
#               precision    recall  f1-score   support
#
#            0       0.41      0.30      0.35      1646
#            1       0.70      0.78      0.74      3354
#
#     accuracy                           0.63      5000
#    macro avg       0.55      0.54      0.54      5000
# weighted avg       0.60      0.63      0.61      5000
#
#
# Linear Discriminant Analysis
#               precision    recall  f1-score   support
#
#            0       0.62      0.17      0.27      1646
#            1       0.70      0.95      0.81      3354
#
#     accuracy                           0.69      5000
#    macro avg       0.66      0.56      0.54      5000
# weighted avg       0.67      0.69      0.63      5000
#
#
# Quadratic Discriminant Analysis
#               precision    recall  f1-score   support
#
#            0       0.60      0.24      0.35      1646
#            1       0.71      0.92      0.80      3354
#
#     accuracy                           0.70      5000
#    macro avg       0.66      0.58      0.57      5000
# weighted avg       0.67      0.70      0.65      5000

# %%
metrics = {
    'Model': [],
    'Accuracy': [],
    'Precision': [],
    'Recall':[]
}
for name,model in models.items():
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    recall=recall_score(y_test,y_pred)
    precision=precision_score(y_test,y_pred)
    metrics['Model'].append(name)
    metrics['Accuracy'].append(acc * 100)
    metrics['Precision'].append(precision * 100)
    metrics['Recall'].append(recall * 100)
    print(f"Model: {name}")
    print(f"Accuracy: {acc*100}")
    print(f"Precision: {precision*100}")
    print(f"Recall: {recall*100}")
    print(f"F1-score: {f1*100}")
    print("-" * 30)
# Out:
# Model: Random Forest Classifier
# Accuracy: 69.86
# Precision: 71.03165565930311
# Recall: 92.99344066785928
# F1-score: 80.54228534538413
# ------------------------------
# Model: Decision Tree Classifier
# Accuracy: 56.54
# Precision: 68.7997453040433
# Recall: 64.43053070960048
# F1-score: 66.54349499615088
# ------------------------------
# Model: AdaBoost Classifier
# Accuracy: 69.36
# Precision: 69.96931170539237
# Recall: 95.16994633273703
# F1-score: 80.6467913087418
# ------------------------------
# Model: Gradient Boosting Classifier
# Accuracy: 70.17999999999999
# Precision: 71.19453924914676
# Recall: 93.29159212880143
# F1-score: 80.75880758807588
# ------------------------------
# Model: Bagging Classifier
# Accuracy: 62.08
# Precision: 70.93624353819644
# Recall: 73.64341085271317
# F1-score: 72.26448215330603
# ------------------------------
# Model: Extra Trees Classifier
# Accuracy: 69.34
# Precision: 70.81142857142856
# Recall: 92.36732259988074
# F1-score: 80.16561004010867
# ------------------------------
# Model: Logistic Regression
# Accuracy: 69.22
# Precision: 69.94943943723896
# Recall: 94.87179487179486
# F1-score: 80.52638238643553
# ------------------------------
# Model: Ridge Classifier
# Accuracy: 68.72
# Precision: 69.3890814558059
# Recall: 95.4979129397734
# F1-score: 80.37641154328733
# ------------------------------
# Model: Perceptron
# Accuracy: 51.160000000000004
# Precision: 67.68813033359193
# Recall: 52.027429934406676
# F1-score: 58.83344571813891
# ------------------------------
# Model: SGD Classifier
# Accuracy: 67.36
# Precision: 67.3169750603379
# Recall: 99.79129397734049
# F1-score: 80.39875090079269
# ------------------------------
# Model: Gaussian Naive Bayes
# Accuracy: 69.26
# Precision: 69.93636164143076
# Recall: 95.02087060226594
# F1-score: 80.57135633927443
# ------------------------------
# Model: Bernoulli Naive Bayes
# Accuracy: 69.08
# Precision: 69.72076788830715
# Recall: 95.28920691711389
# F1-score: 80.52406147644243
# ------------------------------
# Model: Support Vector Classifier (SVC)
# Accuracy: 70.19999999999999
# Precision: 71.18181818181817
# Recall: 93.38103756708408
# F1-score: 80.78411142636058
# ------------------------------
# Model: Nu-Support Vector Classifier
# Accuracy: 61.3
# Precision: 69.7907949790795
# Recall: 74.59749552772809
# F1-score: 72.11413748378729
# ------------------------------
# Model: Linear SVC
# Accuracy: 68.72
# Precision: 69.3890814558059
# Recall: 95.4979129397734
# F1-score: 80.37641154328733
# ------------------------------
# Model: K-Nearest Neighbors
# Accuracy: 62.53999999999999
# Precision: 69.60550701615038
# Recall: 78.3840190816935
# F1-score: 73.73439910251017
# ------------------------------
# Model: Linear Discriminant Analysis
# Accuracy: 69.24
# Precision: 69.98239436619718
# Recall: 94.81216457960645
# F1-score: 80.52671562420866
# ------------------------------
# Model: Quadratic Discriminant Analysis
# Accuracy: 69.72
# Precision: 71.25693160813309
# Recall: 91.94991055456173
# F1-score: 80.29159073158031
# ------------------------------

# %%
num_models = len(models)
rows = (num_models // 3) + (num_models % 3 > 0)
plt.figure(figsize=(15, 5 * rows))

for i, (name, model) in enumerate(models.items(), 1):
    model.fit(x_train, y_train)

    try:
        if hasattr(model, "predict_proba"):  
            y_prob = model.predict_proba(x_test)[:, 1]
        else:
            y_prob = model.decision_function(x_test)
            # Normalize: decision_function genelde min/max dışında kalabilir
            y_prob = (y_prob - np.min(y_prob)) / (np.max(y_prob) - np.min(y_prob))

        fpr, tpr, _ = roc_curve(y_test, y_prob)
        auc_score = auc(fpr, tpr)

        plt.subplot(rows, 3, i)
        plt.plot(fpr, tpr, label=f"AUC: {auc_score:.2f}")
        plt.plot([0, 1], [0, 1], 'k--')
        plt.xlabel("False Positive Rate")
        plt.ylabel("True Positive Rate")
        plt.title(f"ROC Curve - {name}")
        plt.legend()
    
    except Exception as e:
        print(f"{name} için ROC çizilemedi. Hata: {e}")

plt.suptitle("ROC Curve for Different Models", fontsize=16)
plt.subplots_adjust(top=0.9)  # Adjust the top to make room for the title
plt.tight_layout(rect=[0, 0.03, 1, 0.97])  # Adjust layout to make room for the title

plt.show()

# %%
plt.figure(figsize=(12,8))
results=pd.DataFrame(metrics)
sns.barplot(x="Accuracy",y="Model",data=results,color="lightblue")
plt.title("Model Accuracy")
plt.show()

# %%
# 1. Eğitim/test ayrımı
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=42)

# y_train ve y_test'i integer'a dönüştür
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# 2. Veriyi ölçekle
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# 3. Seçilen modeller
models = {
    "Gradient Boosting": GradientBoostingClassifier(),
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "Gaussian Naive Bayes": GaussianNB(),
    "Random Forest": RandomForestClassifier()
}

# 4. Model performanslarını hesapla
results = []

plt.figure(figsize=(15, 4))

for i, (name, model) in enumerate(models.items(), 1):
    # Not: Naive Bayes için orijinal veriler kullanılmalı, çünkü Gauss dağılımı varsayar
    if name == "Gaussian Naive Bayes":
        model.fit(x_train, y_train)
        y_pred = model.predict(x_test)
        y_prob = model.predict_proba(x_test)[:, 1]
    else:
        model.fit(x_train_scaled, y_train)
        y_pred = model.predict(x_test_scaled)
        y_prob = model.predict_proba(x_test_scaled)[:, 1]
    
    acc = accuracy_score(y_test, y_pred)
    prec = precision_score(y_test, y_pred)
    rec = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    auc_score = roc_auc_score(y_test, y_prob)
    
    results.append({
        "Model": name,
        "Accuracy": acc,
        "Precision": prec,
        "Recall": rec,
        "F1 Score": f1,
        "AUC": auc_score
    })
    
    # ROC grafiği çiz
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    plt.subplot(1, 4, i)
    plt.plot(fpr, tpr, label=f"AUC: {auc_score:.2f}")
    plt.plot([0, 1], [0, 1], 'k--')
    plt.title(f"ROC - {name}")
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")
    plt.legend()

plt.tight_layout()
plt.show()

# 5. Sonuçları göster
results_df = pd.DataFrame(results)
print("\nModel Performansları:")
print(results_df.sort_values("AUC", ascending=False).round(3))
# Out:
# Model Performansları:
#                   Model  Accuracy  Precision  Recall  F1 Score    AUC
# 2  Gaussian Naive Bayes     0.680      0.685   0.968     0.802  0.588
# 0     Gradient Boosting     0.702      0.712   0.933     0.808  0.587
# 1   Logistic Regression     0.692      0.699   0.949     0.805  0.587
# 3         Random Forest     0.699      0.711   0.929     0.805  0.578

# %%
# Fonksiyon tanımları
def get_user_input():
    print("Lütfen aşağıdaki 25 soruyu cevaplayınız (Evet=1, Hayır=0).")
    
    user_data = {}

    user_data["Gender"] = int(input("1) Cinsiyetiniz (Kadın:0 / Erkek:1): "))
    user_data["Age"] = int(input("2) Yaşınız: "))
    user_data["Sleep duration"] = float(input("3) Günde ortalama kaç saat uyuyorsunuz?: "))
    user_data["Sleep quality"] = int(input("4) Uyku kalitenizi 1–5 arasında puanlayın: "))
    user_data["Stress level"] = int(input("5) Stres düzeyiniz (1–10 arası): "))
    user_data["Blood pressure"] = int(input("6) Tansiyon durumunuz (0=Düşük, 1=Normal, 2=Yüksek): "))
    user_data["Heart rate"] = int(input("7) Ortalama kalp atış hızınız: "))
    user_data["Daily steps"] = int(input("8) Günlük ortalama attığınız adım sayısı: "))
    user_data["Physical activity"] = int(input("9) Düzenli fiziksel aktivite yapıyor musunuz? (1/0): "))
    user_data["Height"] = float(input("10) Boyunuz (cm): "))
    user_data["Weight"] = float(input("11) Kilonuz (kg): "))
    user_data["Sleep disorder"] = int(input("12) Uyku bozukluğunuz var mı? (1/0): "))
    user_data["Wake up during night"] = int(input("13) Gece sık uyanır mısınız? (1/0): "))
    user_data["Feel sleepy during day"] = int(input("14) Gündüz uykulu hisseder misiniz? (1/0): "))
    user_data["Caffeine consumption"] = int(input("15) Kafein (çay/kahve) tüketiyor musunuz? (1/0): "))
    user_data["Alcohol consumption"] = int(input("16) Alkol tüketiyor musunuz? (1/0): "))
    user_data["Smoking"] = int(input("17) Sigara kullanıyor musunuz? (1/0): "))
    user_data["Medical issue"] = int(input("18) Başka bir sağlık sorununuz var mı? (1/0): "))
    user_data["Ongoing medication"] = int(input("19) Düzenli ilaç kullanıyor musunuz? (1/0): "))
    user_data["Smart device before bed"] = int(input("20) Uyumadan önce telefon/tablet kullanıyor musunuz? (1/0): "))
    user_data["Average screen time"] = float(input("21) Günlük ekran süreniz (saat): "))
    user_data["Blue-light filter"] = int(input("22) Mavi ışık filtresi kullanıyor musunuz? (1/0): "))
    user_data["Discomfort Eye-strain"] = int(input("23) Göz yorgunluğu / rahatsızlık hissediyor musunuz? (1/0): "))
    user_data["Redness in eye"] = int(input("24) Göz kızarıklığı yaşar mısınız? (1/0): "))
    user_data["Itchiness/Irritation in eye"] = int(input("25) Göz kaşıntısı / batma olur mu? (1/0): "))

    return pd.DataFrame([user_data])

def predict_disease(user_df, scaler, models):
    user_scaled = scaler.transform(user_df)

    gb_pred = models["Gradient Boosting"].predict(user_scaled)[0]
    log_pred = models["Logistic Regression"].predict(user_scaled)[0]
    nb_pred = models["Gaussian Naive Bayes"].predict(user_df)[0]
    rf_pred = models["Random Forest"].predict(user_scaled)[0]

    print("\nTahmin Sonuçları")
    print(f"Gradient Boosting: {'HASTA' if gb_pred else 'SAĞLIKLI'}")
    print(f"Logistic Regression: {'HASTA' if log_pred else 'SAĞLIKLI'}")
    print(f"Naive Bayes: {'HASTA' if nb_pred else 'SAĞLIKLI'}")
    print(f"Random Forest: {'HASTA' if rf_pred else 'SAĞLIKLI'}")

    votes = gb_pred + log_pred + nb_pred + rf_pred
    print("\nOrtak Karar:")
    if votes >= 3:
        print("SONUÇ: KULLANICI HASTA")
    elif votes == 2:
        print("SONUÇ: KULLANICI MUHTEMELEN HASTA")
    else:
        print("SONUÇ: KULLANICI SAĞLIKLI")

# %%
# Örnek veri (değerleri kendinize göre değiştirin)
test_data = {
    "Gender": 1,  # Erkek
    "Age": 30,
    "Sleep duration": 7.0,
    "Sleep quality": 3,
    "Stress level": 7,
    "Blood pressure": 1,  # Normal
    "Heart rate": 75,
    "Daily steps": 5000,
    "Physical activity": 1,  # Evet
    "Height": 175.0,
    "Weight": 75.0,
    "Sleep disorder": 0,  # Hayır
    "Wake up during night": 1,  # Evet
    "Feel sleepy during day": 1,  # Evet
    "Caffeine consumption": 1,  # Evet
    "Alcohol consumption": 0,  # Hayır
    "Smoking": 0,  # Hayır
    "Medical issue": 0,  # Hayır
    "Ongoing medication": 0,  # Hayır
    "Smart device before bed": 1,  # Evet
    "Average screen time": 8.0,
    "Blue-light filter": 0,  # Hayır
    "Discomfort Eye-strain": 1,  # Evet
    "Redness in eye": 1,  # Evet
    "Itchiness/Irritation in eye": 1  # Evet
}

# Tahmin yap
test_df = pd.DataFrame([test_data])
predict_disease(test_df, scaler, models)
# Out:
# Tahmin Sonuçları
# Gradient Boosting: HASTA
# Logistic Regression: HASTA
# Naive Bayes: HASTA
# Random Forest: HASTA
#
# Ortak Karar:
# SONUÇ: KULLANICI HASTA
